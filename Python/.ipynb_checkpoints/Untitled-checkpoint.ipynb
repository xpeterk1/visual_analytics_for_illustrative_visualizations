# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import figure

# %%
figure(figsize=(10, 20), dpi=80)
data = pd.read_csv("C:\\Users\\Ondrej\\Desktop\\export.csv")
ids = [0 for _ in range(len(data))]
data["ID"] = ids

# %%
data
# Out:
#          Visible triangles   Projected Area   Visible Area Ratio  \
# 0                -0.053240        -2.635422            -2.586520
# 1                -0.053240        -2.635422            -2.586520
# 2                -0.053240        -2.635422            -2.586520
# 3                -0.053240        -2.635422            -2.586520
# 4                -0.053240        -2.635422            -2.586520
# ...                    ...              ...                  ...
# 1860542           1.123642        -0.878483            -0.802291
# 1860543           1.123642        -0.878483            -0.802291
# 1860544           1.123642        -0.878483            -0.802291
# 1860545           1.123642        -0.878483            -0.802291
# 1860546           1.123642        -0.878483            -0.802291
#
#           Visibility ratio   Viewpoint entropy   Depth Maximizing  \
# 0                 0.759075            2.280968           1.084980
# ...

# %%
figure(figsize=(60, 40), dpi=160)
pd.plotting.parallel_coordinates(data, 'ID')
plt.savefig("output_standardized.png")
